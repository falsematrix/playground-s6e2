# %%
import pandas as pd

path = "/kaggle/input/competitions/stanford-rna-3d-folding-2"
df = pd.read_csv("/kaggle/input/competitions/stanford-rna-3d-folding-2/test_sequences.csv")
df.shape
# Out:
# (28, 8)
